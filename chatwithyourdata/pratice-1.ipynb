# %%
import os
from langchain_openai import AzureChatOpenAI
from langchain_community.document_loaders import WebBaseLoader, PyPDFLoader

os.environ["USER_AGENT"] = "MyLangchainBot/1.0 (contact@example.com)"

# %%
pdf_file = PyPDFLoader(".//MachineLearning01.pdf")
pages = pdf_file.load()
print(f"Number of pages: {len(pages)}")
# Out:
# Number of pages: 22

# %%
print(pages[0].page_content[:1000])  # Print the first 1000 characters of the first page

# %%
loader = WebBaseLoader("https://directdevops.blog")
web_pages = loader.load()
print(web_pages[0].page_content[:])  # Print the first 1000 characters of the first web page
# Out:
# Direct DevOps from Quality Thought
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Skip to content
#
#
#
# Direct DevOps from Quality Thought
#
#
#
#
# Menu
# Close
#
#
# Home
# DevOps Classroom Daily Notes
# Multi-Cloud Classroom Notes
# GCP DevOps Class Notes
# AWS Classroom Notes
# Azure Classroom Notes
# Complete Kubernetes Course
# Books For Quick Reference By Khaja
# Kubernetes Classroom Notes
# AWS & AZURE Material (From QT Blog)
# DevOps Blog (From QT Blog)
# Scripting Sessions
# Foundation Series NotesOpen menu
#
# Linux Foundation Notes
# Windows Powershell Notes
# Active Directory Notes
# Vagrant Class Notes
#
#
# Foundation Series VideosOpen menu
#
# Linux Foundation Videos
# Windows Powershell Videos
# Active Directory Videos
# Vagrant Class Videos
#
#
# Essentials
# Challenges
# Linux Blog
# Contact
# Privacy Policy
#
#
#
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter, CharacterTextSplitter

text = "This is a long document that needs to be split into smaller chunks."

splitter = RecursiveCharacterTextSplitter(chunk_size=50, chunk_overlap=0)
chunks = splitter.split_text(text)

print(chunks)
# Out:
# ['This is a long document that needs to be split', 'into smaller chunks.']

# %%
chunk_size = 26
chunk_overlap = 5
r_splitter = RecursiveCharacterTextSplitter(
    chunk_size=chunk_size, chunk_overlap=chunk_overlap
)
c_splitter = CharacterTextSplitter(
    chunk_size=chunk_size, chunk_overlap=chunk_overlap
)
r_chunks = r_splitter.split_documents(pages)
c_chunks = c_splitter.split_documents(pages)

# %%
print(f"Recursive Character Text Splitter: {r_chunks} chunks")
# Out:
# Recursive Character Text Splitter: [] chunks

# %%
text2 = "abcdefghijklmnopqrstuvwxyz abcdefghijklmnopqrstuvwxyza"
r_chunks2 = r_splitter.split_text(text2)
print(f"Recursive Character Text Splitter: {r_chunks2} chunks")
c_chunks2 = c_splitter.split_text(text2)
print(f"Character Text Splitter: {c_chunks2} chunks")
# Out:
# Recursive Character Text Splitter: ['abcdefghijklmnopqrstuvwxyz', 'abcdefghijklmnopqrstuvwxy', 'uvwxyza'] chunks
# Character Text Splitter: ['abcdefghijklmnopqrstuvwxyz abcdefghijklmnopqrstuvwxyza'] chunks

# %%
vaishnav = PyPDFLoader(".//108_vaishnavite_divya_desams_vol_3.pdf")
vaishnav_pages = vaishnav.load()
print(f"Number of pages in Vaishnav PDF: {len(vaishnav_pages)}")
# Out:
# Number of pages in Vaishnav PDF: 305

# %%
page = vaishnav_pages[1]
print(f"First page content: {page.page_content[:]}")
  # Print the first 1000 characters of the first page
print(page.metadata)
# Example Output: {'source': 'file.pdf', 'page': 0}
# Out:
# First page content:
# {'producer': 'Adobe Acrobat 7.0 Image Conversion Plug-in', 'creator': 'Adobe Acrobat 7.0', 'creationdate': '2012-03-14T03:25:24+05:30', 'moddate': '2012-03-14T03:25:34+05:30', 'source': './/108_vaishnavite_divya_desams_vol_3.pdf', 'total_pages': 305, 'page': 1, 'page_label': '2'}

# %%
from langchain_community.document_loaders import UnstructuredPDFLoader

loader = PyPDFLoader("./108_vaishnavite_divya_desams_vol_3.pdf")
documents = loader.load()

print(f"Total extracted segments: {len(documents)}")
print(documents[0].page_content[:500])
# Out:
# Total extracted segments: 305
